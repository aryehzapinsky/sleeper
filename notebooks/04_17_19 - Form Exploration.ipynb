# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

# %%
sleep_df = pd.read_csv('Sleep Review (Responses) - Form Responses 1.csv')

# %%
sleep_df = sleep_df.rename(columns={'Unnamed: 7':'Caffiene'})

# %%
display(sleep_df)
# Out:
#               Timestamp             Section  Hours  Rate sleep  \
# 0     3/12/2019 6:12:07                 NaN    5.0         3.0
# 1     3/13/2019 0:50:26  Sleep anticipation    NaN         NaN
# 2     3/13/2019 6:07:01        Sleep Review    5.0         3.0
# 3     3/13/2019 6:49:38       Coffee or tea    NaN         NaN
# 4     3/13/2019 9:55:03       Coffee or tea    NaN         NaN
# 5    3/13/2019 18:20:16       Coffee or tea    NaN         NaN
# 6     3/14/2019 1:12:10  Sleep anticipation    NaN         NaN
# 7     3/14/2019 6:09:18        Sleep Review    5.0         3.0
# 8    3/14/2019 10:20:33       Coffee or tea    NaN         NaN
# 9    3/14/2019 10:21:03       Coffee or tea    NaN         NaN
# 10   3/14/2019 21:29:54       Coffee or tea    NaN         NaN
# 11    3/15/2019 1:04:37  Sleep anticipation    NaN         NaN
# 12    3/15/2019 6:34:49        Sleep Review    5.5         4.0
# 13    3/17/2019 1:29:28  Sleep anticipation    NaN         NaN
# ...

# %%
sleep_df[['Timestamp','Caffiene']]
sleep_df['Timestamp'] = pd.to_datetime(sleep_df['Timestamp'])

# %%
sns.lineplot()
plt.show()
